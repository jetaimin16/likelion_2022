# %% [markdown]
# # CH 2

# %% [markdown]
# ## Step 2. 크롤러 알아보기
# web crawling: 크롤러를 사용해 웹 페이지의 데이터를 추출해내는 행위

# %% [markdown]
# ## Step 3. 블록 조립 키트
# - 함수(function): 자주 쓰는 코드들을 묶어놓은 것
#     - 조립 기계(갈색 블록, 초록색 블록)
# - 모듈(module): 자주 쓰는 함수들을 모아놓은 파일
#     - 마을 조립 키트: 마을을 만들기 위한 기계들의 모음

# %% [markdown]
# ## Step 4. 블록 조립 키트 사용법
# 1. requests 모듈에서
# 2. get 함수(return 응답값)를 꺼내
# 3. 요청을 보내줘

# %% [markdown]
# ## Step 5. 요청하고 응답받기
# - import requests
# - requests.get(url): GET 요청을 보내는 기능
#     - Client: 요청
#     - Server: 응답(html 정보)

# %%
import requests # 사용하고자 하는 모듈 명시

print(requests) # request 저장 경로
# Out:
# <module 'requests' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\requests\\__init__.py'>

# %%
print(requests.get) # "function" get
# Out:
# <function get at 0x0000024AEE7EBCA0>

# %% [markdown]
# ## Step 6. 요청하고 응답받기 2
# - requests.get(url, params=None, **kwargs)
#     - return: requests.Response

# %% [markdown]
# ## Step 7. 요청하고 응답받기 3

# %%
import requests

url = "http://www.daum.net"
print(requests.get(url)) 
# Response [200]: 요청 성공

response = requests.get(url)
print(response.text) # html 코드를 모두 가져옴
# print(response.url)
# print(response.content)
# print(response.encoding)
# print(response.headers)
# print(response.json)
# print(response.links)
# print(response.ok)
# print(response.status_code)
# Out:
# <Response [200]>
# ...

# %% [markdown]
# ## Step 8. Beautiful Soup 1
# - bs4 모듈의 BeautifulSoup
#     - BeautifulSoup(response.text, 'html.parser')

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.daum.net"
response = requests.get(url)
print(BeautifulSoup(response.text, "html.parser"))
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ## Step 9. Beautiful Soup 2
# - bs4.BeautifulSoup type: 칸막이별로 정리된 정보

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.daum.net"
response = requests.get(url)
print(type(response.text)) # str
print(type(BeautifulSoup(response.text, "html.parser"))) # bs4.BeautifulSoup
# Out:
# <class 'str'>
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# ## Step 10. Beautiful Soup 3
# - BeautifulSoup(data, parsing 방법)
#     - data: 통에 담을 데이터 - requests를 통해 받아온 정보(HTML or XML)
#     - parsing: data를 의미있게 변경하는 작업 - html.parser: 파이썬에 내장된 parser'

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.daum.net"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")
print(soup.title) # title 태그를 가져옴
# Out:
# <title>Daum</title>

# %% [markdown]
# ## Step 11. Beautiful Soup 4
# - soup.tag.string: 태그 내의 문자 가져오기
# - soup.findAll('tag'): 해당 태그 모든 정보 가져오기

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.daum.net/"
response = requests.get(url)
#print(response.text[:500])

soup = BeautifulSoup(response.text, "html.parser")
print(soup.title.string) # title 태그 내의 문자를 가져옴
print(soup.span)
print(soup.findAll('span')) # 모든 span 태그 가져옴
# Out:
# []

# %% [markdown]
# ## Step 12. Beautiful Soup 5

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.daum.net/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# 가져온 정보 파일로 저장
file = open("daum.html", "w", encoding='utf-8')
file.write(response.text)
file.close()

# %% [markdown]
# ## Step 13. Beautiful Soup 6
# - soup.findAll("tag", "class"): tag 내 class에 담긴 정보 가져오기

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.daum.net/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# html 문서에서 a 태그의 link_favorsch 클래스를 가져오는 코드
results = soup.findAll("a", "link_favorsch")
# Out:
# []

# %% [markdown]
# ## Step 14. 예쁘게 출력하기
# - datetime 모듈
#     - datetime.today().strftime("%Y년 %m월 %d일")

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime

url = "http://www.daum.net/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

results = soup.findAll("a", "link_favorsch")
rank = 1

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n")) # 현재 날짜 출력

for result in results:
    print(rank, "위:", result.get_text(), "\n")
    rank += 1
# Out:
# 2022년 05월 06일의 실시간 검색어 순위입니다.

# %% [markdown]
# ## Step 15. 파일로 출력하기
# - open(file, mode)
#     - mode: r(read), w(write), a(append)

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime

url = "http://www.daum.net/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

results = soup.findAll("a", "link_favorsch")
rank = 1

search_rank_file = open("rankresult.txt", "w")

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n")) # 현재 날짜 출력

for result in results:
    search_rank_file.write(str(rank) +"위: "+result.get_text()+'\n')
    print(rank, "위:", result.get_text(), "\n")
    rank += 1
# Out:
# 2022년 05월 06일의 실시간 검색어 순위입니다.

# %% [markdown]
# ## Step 16. 응용해보기
# - 네이버 실시간 검색어 크롤링

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
# headers: 로봇이 아니라는 정보 전달 필요
url = "https://datalab.naver.com/keyword/realtimeList.naver?age=20s"
response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")

results = soup.findAll("span", "item_title")
rank = 1

for result in results:
    search_rank_file.write(str(rank) +"위: "+result.get_text()+'\n')
    print(rank, "위:", result.get_text(), "\n")
    rank += 1

# %% [markdown]
# # CH 3

# %% [markdown]
# ## Step 1. API Key 발급받기

# %% [markdown]
# ## Step 2. 미리보기

# %% [markdown]
# ## Step 3. API 알아보기
# - API(Application Programming Interface)
#     - Interface: Client와 Server간의 매개체(연결고리)

# %% [markdown]
# ## Step 4. API Key 알아보기

# %% [markdown]
# ## Step 5. API 링크 만들기
# - API doc에서 정보 확인
# - f-string을 이용해 api에 city와 apikey 넣기

# %%
city = "Seoul"
apikey = "eb1aff6d2c99b8e69ef98bb1c4396f66"
api = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={apikey}"

print(api)
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=Seoul&appid=eb1aff6d2c99b8e69ef98bb1c4396f66

# %% [markdown]
# ## Step 6. 날씨 받아오기
# - api 서버주소: https://api.openweathermap.org/data/2.5/weather?q={city}&appid={apikey}
#   - ? 앞쪽은 공통 url
#   - ? 뒤쪽은 parameter로, 요청값을 의미
# - requests 모듈을 사용해 api 서버주소 내의 값 가져오기

# %%
import requests

city = "Seoul"
apikey = "eb1aff6d2c99b8e69ef98bb1c4396f66"
api = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={apikey}"

result = requests.get(api)
print(result.text)
# Out:
# {"coord":{"lon":126.9778,"lat":37.5683},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}],"base":"stations","main":{"temp":296.53,"feels_like":296.07,"temp_min":291.84,"temp_max":297.93,"pressure":1015,"humidity":44},"visibility":10000,"wind":{"speed":5.66,"deg":280},"clouds":{"all":40},"dt":1651827056,"sys":{"type":1,"id":8105,"country":"KR","sunrise":1651782708,"sunset":1651832737},"timezone":32400,"id":1835848,"name":"Seoul","cod":200}

# %% [markdown]
# ## Step 7. 예쁘게 출력하기 1
# - 파이썬의 json 모듈
#   - json(javascript object notation): 데이터를 주고 받을 때 사용하는 포맷
#   - json.load(text)

# %%
import requests
import json

city = "Seoul"
apikey = "eb1aff6d2c99b8e69ef98bb1c4396f66"
api = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={apikey}"

result = requests.get(api)
data = json.loads(result.text)
print(type(data)) # dict
# Out:
# <class 'dict'>

# %% [markdown]
# ## Step 8, 9. 예쁘게 출력하기 2, 3

# %%
import requests
import json

city = "Seoul"
apikey = "eb1aff6d2c99b8e69ef98bb1c4396f66"
api = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={apikey}"

result = requests.get(api)
data = json.loads(result.text)

print(data["name"], "의 날씨입니다.")
print("날씨는", data["weather"][0]["description"], "입니다.")
print("현재 온도는", data["main"]["temp"], "입니다.")
print("하지만 체감 온도는", data["main"]["feels_like"], "입니다.")
print("최저 기온은", data["main"]["temp_min"], "입니다.")
print("최고 기온은", data["main"]["temp_max"], "입니다.")
print("습도는", data["main"]["humidity"], "입니다.")
print("기압은", data["main"]["pressure"], "입니다.")
print("풍향은", data["wind"]["deg"], "입니다.")
print("풍속은", data["wind"]["speed"], "입니다.")
# Out:
# Seoul 의 날씨입니다.
# 날씨는 overcast clouds 입니다.
# 현재 온도는 297.81 입니다.
# 하지만 체감 온도는 297.66 입니다.
# 최저 기온은 291.84 입니다.
# 최고 기온은 297.81 입니다.
# 습도는 51 입니다.
# 기압은 1015 입니다.
# 풍향은 267 입니다.
# 풍속은 3.96 입니다.

# %% [markdown]
# ## Step 10. 언어 및 단위 변경하기
# - language값 추가: 한국어로 변경
#   - api 파라미터에 lang={kr} 추가
# - 화씨를 섭씨로 변경
#   - api 파라미터에 units=metric 추가

# %%
import requests
import json

city = "London"
apikey = "eb1aff6d2c99b8e69ef98bb1c4396f66"
lang = "kr"
#units = "metric"
api = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={apikey}&lang={lang}&units=metric"

result = requests.get(api)
data = json.loads(result.text)

print(data["name"], "의 날씨입니다.")
print("날씨는", data["weather"][0]["description"], "입니다.")
print("현재 온도는", data["main"]["temp"], "입니다.")
print("하지만 체감 온도는", data["main"]["feels_like"], "입니다.")
print("최저 기온은", data["main"]["temp_min"], "입니다.")
print("최고 기온은", data["main"]["temp_max"], "입니다.")
print("습도는", data["main"]["humidity"], "입니다.")
print("기압은", data["main"]["pressure"], "입니다.")
print("풍향은", data["wind"]["deg"], "입니다.")
print("풍속은", data["wind"]["speed"], "입니다.")
# Out:
# London 의 날씨입니다.
# 날씨는 튼구름 입니다.
# 현재 온도는 17.18 입니다.
# 하지만 체감 온도는 16.68 입니다.
# 최저 기온은 14.73 입니다.
# 최고 기온은 18.91 입니다.
# 습도는 66 입니다.
# 기압은 1026 입니다.
# 풍향은 260 입니다.
# 풍속은 3.09 입니다.
